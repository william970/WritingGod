# %%
import cv2
import matplotlib.pyplot as plt
binary = cv2.imread("demo.jpg")
print(binary.shape)
x = [1570]
plt.figure(figsize=(10,10))
plt.yticks(x)
plt.imshow(binary)
plt.show()
# Out:
# (1920, 1080, 3)

# %%
cv2.imwrite("demo2.jpg",th2)
# Out:
# True
