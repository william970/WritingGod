# %%
import cv2 as cv

# %%
a = cv2.imread('Screenshot_2020-11-01-18-14-14.png')

# %%
def local_threshold(image):
    gray = cv.cvtColor(image, cv.COLOR_RGB2GRAY)  #把输入图像灰度化
    #自适应阈值化能够根据图像不同区域亮度分布，改变阈值
    binary =  cv.adaptiveThreshold(gray, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY, 25, 10)

    plt.imshow("binary1", binary)

# %%
local_threshold(a)

# %%
import cv2
import matplotlib.pyplot as plt
#相对路径下读取图片
doge = cv2.imread('Screenshot_2020-11-01-18-14-14.png')
#灰度化处理
grayImage= cv2.cvtColor(doge,cv2.COLOR_BGR2GRAY)
#cv2.imshow('GRAY',grayImage)

grayImage.shape
plt.figure(1)
plt.imshow(grayImage)

# %%
ret, binary = cv.threshold(grayImage, 0, 255, 20)

# %%
threshold(gray, binary, 180, 255, CV_THRESH_BINARY)

# %%
ret,thresh1 = cv2.threshold(grayImage,185,255,cv2.THRESH_BINARY)
plt.imshow(thresh1)
cv.imwrite("asd.png",thresh1)
# Out:
# True
